# %%
# 출처1 : https://pinkwink.kr/1005
# 출처2 : http://nbviewer.jupyter.org/gist/hyeshik/cf9f3d7686e07eedbfda?revision=6

# %% [markdown]
# + [x] 1.사전준비(import)
# + [x] 2.자료 불러오기(Excel read)
# + [x] 3.함수 만들기
# + [x] 4.그래프 그리기
#   + [x] A. 한국 인구 분포
#   + [x] B. 회원수 분포
#   + [x] C. 외식매장 쿠폰이용 분포
#   + [x] D. 분유적립(Y/N)
#   + [x] E. 온라인 구매
#   + [x] F. SMS 수신동의
#   + [x] G. 아기수
#   + [x] H. 분유적립캔수(누적)
#   + [x] I. 아기1명당 분유적립

# %% [markdown]
# ## 1.사전준비

# %%
import pandas as pd
import numpy as np

import platform
import matplotlib.pyplot as plt

# %matplotlib inline

from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')    

plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 2.자료 불러오기(Excel)

# %%
# data_draw_korea = pd.read_csv('./data_draw_korea.csv', index_col=0, encoding='UTF-8')

# data_draw_korea.to_excel('data_MP.xlsx', sheet_name= 'sheet1' ,index=False)
data_draw_korea=pd.read_excel('./data_GIS.xlsx','sheet1')

data_draw_korea.tail(15)
# Out:
#      광역시도 행정구역 shortName  x   y     인구수      면적    회원수  쿠폰이용  분유적립  온라인 구매  \
# 214  충청남도  천안시        천안  4   9  584912  636.50  12632    78  3757    5155
# 215  충청남도  청양군        청양  3  11   29671  479.67    247     0    60     111
# 216  충청남도  태안군        태안  1   9   56489  504.82    610     0   137     259
# 217  충청남도  홍성군        홍성  2  10   87904  443.90   1638     1   456     640
# 218  충청북도  괴산군        괴산  7  11   33297  842.00    145     0    41      65
# 219  충청북도  단양군        단양  7  10   27130  781.07    260     0    97     133
# 220  충청북도  보은군        보은  7  12   30685  584.45    213     0    85      93
# 221  충청북도  영동군        영동  6  14   46524  845.01    350     0    97     153
# 222  충청북도  옥천군        옥천  6  13   47599  537.13    405     0   145     195
# 223  충청북도  음성군        음성  5  10   86441  521.05   1510     1   492     643
# 224  충청북도  제천시        제천  8  10  127462  882.47   2518     1   877    1090
# ...

# %% [markdown]
# ## 3.지도좌표 구성하기

# %%
BORDER_LINES = [
    [(3, 2), (5, 2), (5, 3), (9, 3), (9, 1)], # 인천
    [(2, 5), (3, 5), (3, 4), (8, 4), (8, 7), (7, 7), (7, 9), (4, 9), (4, 7), (1, 7)], # 서울
    [(1, 6), (1, 9), (3, 9), (3, 10), (8, 10), (8, 9),
     (9, 9), (9, 8), (10, 8), (10, 5), (9, 5), (9, 3)], # 경기도
    [(9, 12), (9, 10), (8, 10)], # 강원도
    [(10, 5), (11, 5), (11, 4), (12, 4), (12, 5), (13, 5),
     (13, 4), (14, 4), (14, 2)], # 충청남도
    [(11, 5), (12, 5), (12, 6), (15, 6), (15, 7), (13, 7),
     (13, 8), (11, 8), (11, 9), (10, 9), (10, 8)], # 충청북도
    [(14, 4), (15, 4), (15, 6)], # 대전시
    [(14, 7), (14, 9), (13, 9), (13, 11), (13, 13)], # 경상북도
    [(14, 8), (16, 8), (16, 10), (15, 10),
     (15, 11), (14, 11), (14, 12), (13, 12)], # 대구시
    [(15, 11), (16, 11), (16, 13)], # 울산시
    [(17, 1), (17, 3), (18, 3), (18, 6), (15, 6)], # 전라북도
    [(19, 2), (19, 4), (21, 4), (21, 3), (22, 3), (22, 2), (19, 2)], # 광주시
    [(18, 5), (20, 5), (20, 6)], # 전라남도
    [(16, 9), (18, 9), (18, 8), (19, 8), (19, 9), (20, 9), (20, 10)], # 부산시
]

gamma = 0.75

blockedMap = data_draw_korea
targetData = '인구수'

whitelabelmin = (max(blockedMap[targetData]) - min(blockedMap[targetData])) * 0.25 + min(blockedMap[targetData])

datalabel = targetData

vmin = min(blockedMap[targetData])
vmax = max(blockedMap[targetData])

mapdata = blockedMap.pivot(index='y', columns='x', values=targetData)
masked_mapdata = np.ma.masked_where(np.isnan(mapdata), mapdata)

# %% [markdown]
# ## 3. 함수 만들기

# %%
def drawKorea(targetData, blockedMap, d1, d2, cmapname):
    gamma = 0.75

    whitelabelmin = (max(blockedMap[targetData]) - min(blockedMap[targetData])) * 0.25 + min(blockedMap[targetData])

    datalabel = targetData

    vmin = min(blockedMap[targetData])
    vmax = max(blockedMap[targetData])

    BORDER_LINES = [
        [(3, 2), (5, 2), (5, 3), (9, 3), (9, 1)], # 인천
        [(2, 5), (3, 5), (3, 4), (8, 4), (8, 7), (7, 7), (7, 9), (4, 9), (4, 7), (1, 7)], # 서울
        [(1, 6), (1, 9), (3, 9), (3, 10), (8, 10), (8, 9),
         (9, 9), (9, 8), (10, 8), (10, 5), (9, 5), (9, 3)], # 경기도
        [(9, 12), (9, 10), (8, 10)], # 강원도
        [(10, 5), (11, 5), (11, 4), (12, 4), (12, 5), (13, 5),
         (13, 4), (14, 4), (14, 2)], # 충청남도
        [(11, 5), (12, 5), (12, 6), (15, 6), (15, 7), (13, 7),
         (13, 8), (11, 8), (11, 9), (10, 9), (10, 8)], # 충청북도
        [(14, 4), (15, 4), (15, 6)], # 대전시
        [(14, 7), (14, 9), (13, 9), (13, 11), (13, 13)], # 경상북도
        [(14, 8), (16, 8), (16, 10), (15, 10),
         (15, 11), (14, 11), (14, 12), (13, 12)], # 대구시
        [(15, 11), (16, 11), (16, 13)], # 울산시
        [(17, 1), (17, 3), (18, 3), (18, 6), (15, 6)], # 전라북도
        [(19, 2), (19, 4), (21, 4), (21, 3), (22, 3), (22, 2), (19, 2)], # 광주시
        [(18, 5), (20, 5), (20, 6)], # 전라남도
        [(16, 9), (18, 9), (18, 8), (19, 8), (19, 9), (20, 9), (20, 10)], # 부산시
    ]

    mapdata = blockedMap.pivot(index='y', columns='x', values=targetData)
    masked_mapdata = np.ma.masked_where(np.isnan(mapdata), mapdata)
    
    plt.figure(figsize=(8, 13))
    plt.pcolor(masked_mapdata, vmin=vmin, vmax=vmax, cmap=cmapname, edgecolor='#aaaaaa', linewidth=0.5)

    # 지역 이름 표시
    for idx, row in blockedMap.iterrows():
        annocolor = 'white' if row[targetData] > whitelabelmin else 'black'

        # 광역시는 구 이름이 겹치는 경우가 많아서 시단위 이름도 같이 표시한다. (중구, 서구)
        if row[d1].endswith('시') and not row[d1].startswith('세종'):
            dispname = '{}\n{}'.format(row[d1][:2], row[d2][:-1])
            if len(row[d2]) <= 2:
                dispname += row[d2][-1]
        else:
            dispname = row[d2][:-1]

        # 서대문구, 서귀포시 같이 이름이 3자 이상인 경우에 작은 글자로 표시한다.
        if len(dispname.splitlines()[-1]) >= 3:
            fontsize, linespacing = 9.5, 1.5
        else:
            fontsize, linespacing = 11, 1.2

        plt.annotate(dispname, (row['x']+0.5, row['y']+0.5), weight='bold',
                     fontsize=fontsize, ha='center', va='center', color=annocolor,
                     linespacing=linespacing)
        
    # 시도 경계 그린다.
    for path in BORDER_LINES:
        ys, xs = zip(*path)
        plt.plot(xs, ys, c='black', lw=4)

    plt.gca().invert_yaxis()
    #plt.gca().set_aspect(1)

    plt.axis('off')

    cb = plt.colorbar(shrink=.1, aspect=10)
    cb.set_label(datalabel)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 4.그래프 그리기

# %%
drawKorea('인구수', data_draw_korea, '광역시도', '행정구역', 'Blues')

# %%
drawKorea('회원수', data_draw_korea, '광역시도', '행정구역', 'Oranges')

# %%
drawKorea('쿠폰이용', data_draw_korea, '광역시도', '행정구역', 'Greys')

# %%
drawKorea('분유적립', data_draw_korea, '광역시도', '행정구역', 'Greens')

# %%
drawKorea('온라인 구매', data_draw_korea, '광역시도', '행정구역', 'Reds')

# %%
drawKorea('SMS 수신동의', data_draw_korea, '광역시도', '행정구역', 'BuGn')

# %%
drawKorea('아기수', data_draw_korea, '광역시도', '행정구역', 'YlOrBr')

# %%
drawKorea('분유캔수(누적)', data_draw_korea, '광역시도', '행정구역', 'OrRd')

# %%
drawKorea('아기1명당 분유적립', data_draw_korea, '광역시도', '행정구역', 'seismic')
