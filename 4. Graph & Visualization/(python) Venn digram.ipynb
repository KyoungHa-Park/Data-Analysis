# %% [markdown]
# # Index
# + [x] 2-group Venn diagram
# + [x] 3-group Venn diagram
# + [x] 4-group Venn diagram
# + [ ] 5-group Venn diagram

# %%
# pip install pyvenny

# %% [markdown]
# ### 2-group Venn diagram

# %%
# Import the library
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

import matplotlib.font_manager as fm
path = 'C:/windows/Fonts/malgun.ttf'                           # 폰트:맑은고딕
font_name = fm.FontProperties(fname=path, size=24).get_name()  
plt.rc('font', family=font_name)

# %%
c= venn2(subsets = (1060, 600, 136), set_labels = ('CYJ', 'KSF'))
c.get_patch_by_id('10').set_color('purple')
c.get_patch_by_id('01').set_color('red')
c.get_patch_by_id('11').set_color('gray')
plt.show()

# %% [markdown]
# ### 3-group Venn diagram

# %%
# Import the library
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

import matplotlib.font_manager as fm
path = 'C:/windows/Fonts/malgun.ttf'                           # 폰트:맑은고딕
font_name = fm.FontProperties(fname=path, size=24).get_name()  
plt.rc('font', family=font_name)                               # 한글폰트 설정(전역)

# %%
# Make the diagram
# venn3(subsets = (2728,65,17,468,97,18,7), set_labels = ('1만원 권', '3만원 권', '5만원 권'))
c= venn3(subsets = (26012,559,501,465,137,48,89), set_labels = ('PBS', 'CYJ', 'KSF'))
c.get_patch_by_id('100').set_color('gray')
c.get_patch_by_id('010').set_color('purple')
c.get_patch_by_id('001').set_color('red')
plt.show()

# %%
# Make the diagram
venn3(subsets = (4987,1961,409,25426,6616,2620,1230), set_labels = ('소잘', '소잘외', '미변경'))
plt.show()

# %%
# 5만원 권종
# Make the diagram
c= venn3(subsets = (246,33,37,240,16,9,2), set_labels = ('폴 바셋', '그 외', '0to7'))
c.get_patch_by_id('10').set_color('gray')
# c.get_patch_by_id('01').set_edgecolor('none')
# c.get_patch_by_id('10').set_alpha(0.4)
# c.get_patch_by_id('01').set_alpha(0.4)
plt.show()

# %%
# 1만원 권종
# Make the diagram
c= venn3(subsets = (2716,57,39,91,54,10,6), set_labels = ('폴 바셋', '그 외', '0to7'))
c.get_patch_by_id('10').set_color('gray')
# c.get_patch_by_id('01').set_edgecolor('none')
# c.get_patch_by_id('10').set_alpha(0.4)
# c.get_patch_by_id('01').set_alpha(0.4)
plt.show()

# %%
# 3만원 권종
# Make the diagram
c= venn3(subsets = (76,4,9,14,2,0,0), set_labels = ('폴 바셋', '그 외', '0to7'))
c.get_patch_by_id('10').set_color('gray')
# c.get_patch_by_id('01').set_edgecolor('none')
# c.get_patch_by_id('10').set_alpha(0.4)
# c.get_patch_by_id('01').set_alpha(0.4)
plt.show()

# %%
# Make the diagram
c= venn3(subsets = (104,9018,293,1194,55,5908,504), set_labels = ('디카페인', '16시 이후', '1일 2잔'))
c.get_patch_by_id('10').set_color('gray')
# c.get_patch_by_id('01').set_edgecolor('none')
# c.get_patch_by_id('10').set_alpha(0.4)
# c.get_patch_by_id('01').set_alpha(0.4)
plt.show()

# %% [markdown]
# ### 4-group Venn diagram

# %%
import venn  # 출처 : https://github.com/tctianchi/pyvenn

# %%
labels = {'0001': '983',
          '0010': '7615',
          '0011': '2485',
          '0100': '79',
          '0101': '37',
          '0110': '226',
          '0111': '313',
          '1000': '795',
          '1001': '211',
          '1010': '1403',
          '1011': '1623',
          '1100': '25',
          '1101': '18',
          '1110': '67',
          '1111': '191'}

# %%
# labels = venn.get_labels([range(10), labels], fill=['number', 'logic'])
fig, ax = venn.venn4(labels, names=['소잘변경', '디카페인', '4시이후', '1일2회'])
fig.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
labels = {'0001': '4987',
          '0010': '1335',
          '0011': '572',
          '0100': '25426',
          '0101': '0101: 5',
          '0110': '0110: 0',
          '0111': '0111: 0',
          '1000': '1000: 3',
          '1001': '1001: 0',
          '1010': '1010: 2',
          '1011': '1011: 0',
          '1100': '1100: 0',
          '1101': '1101: 2',
          '1110': '1110: 3',
          '1111': '87'}

# %%
venn.venn4(labels, names=['소잘', '저지방', '두유', '미변경'])
# Out:
# (<Figure size 1152x1152 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x26130863cf8>)
