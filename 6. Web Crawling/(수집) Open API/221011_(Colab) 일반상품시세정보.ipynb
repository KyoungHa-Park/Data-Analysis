# %%
# https://www.data.go.kr/tcs/dss/selectApiDataDetailView.do?publicDataPk=15094805

# %%
import requests
import re
from pandas import json_normalize
import pandas as pd
from datetime import datetime, timedelta
import time 
import json

# %%
url = 'https://apis.data.go.kr/1160100/service/GetGeneralProductInfoService/getOilPriceInfo?serviceKey=7TF3DZB/E1jVpaj4/EMdykMU1ur0mo4kEmWzN5M+L3hGoEFgO7qpmX/QH5QoD8NexZcqsTn0/6TWMpjGiNpYrw==&stdt=20221002&resultType=json'
# lm_json = requests.post(url, verify=False)

# %%
AUTHKEY = '__AUTHKEY__'
STDT = (datetime.today() + timedelta(hours=0) - timedelta(0)).strftime('%Y%m%d')
url = 'https://apis.data.go.kr/1160100/service/GetGeneralProductInfoService/getOilPriceInfo?serviceKey='+AUTHKEY + '&resultType=json&stdt=' + str(STDT)
# lm_json = requests.get(url)

# %%
STDT
# Out:
# '20230411'

# %%
import ssl

from urllib3 import PoolManager
from urllib3.util.ssl_ import create_urllib3_context

ctx = create_urllib3_context()
ctx.load_default_certs()
ctx.options |= ssl.OP_ENABLE_MIDDLEBOX_COMPAT

with PoolManager(ssl_context=ctx) as pool:
    resp = pool.request("GET", url)

# %%
data = json.loads(resp.data)

# %%
# data['response']['body']['items']['item']

# %%
data
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'numOfRows': 10,
#    'pageNo': 1,
#    'totalCount': 2428,
#    'items': {'item': [{'basDt': '20230410',
#       'oilCtg': '경유',
#       'wtAvgPrcCptn': '1366.62',
#       'wtAvgPrcDisc': '1356.67',
#       'trqu': '13112000',
#       'trPrc': '17837220000'},
#      {'basDt': '20230410',
#       'oilCtg': '등유',
#       'wtAvgPrcCptn': '1003.85',
#       'wtAvgPrcDisc': '992.19',
#       'trqu': '4032000',
#       'trPrc': '4010200000'},
#      {'basDt': '20230410',
#       'oilCtg': '휘발유',
#       'wtAvgPrcCptn': '1514.12',
#       'wtAvgPrcDisc': '1517.16',
#       'trqu': '7796000',
#       'trPrc': '11822600000'},
#      {'basDt': '20230407',
#       'oilCtg': '경유',
#       'wtAvgPrcCptn': '1427.89',
#       'wtAvgPrcDisc': '1361.09',
#       'trqu': '6376678',
#       'trPrc': '8704616724'},
#      {'basDt': '20230407',
#       'oilCtg': '등유',
#       'wtAvgPrcCptn': '1080',
#       'wtAvgPrcDisc': '990',
#       'trqu': '146129',
#       'trPrc': '146467710'},
#      {'basDt': '20230407',
#       'oilCtg': '휘발유',
#       'wtAvgPrcCptn': '1580',
#       'wtAvgPrcDisc': '1531.22',
#       'trqu': '3895058',
#       'trPrc': '5974918740'},
#      {'basDt': '20230406',
#       'oilCtg': '경유',
#       'wtAvgPrcCptn': '1359.59',
#       'wtAvgPrcDisc': '1404.33',
#       'trqu': '9484161',
#       'trPrc': '13078209583'},
#      {'basDt': '20230406',
#       'oilCtg': '등유',
#       'wtAvgPrcCptn': '1000',
#       'wtAvgPrcDisc': '1013.64',
#       'trqu': '720009',
#       'trPrc': '723008910'},
#      {'basDt': '20230406',
#       'oilCtg': '휘발유',
#       'wtAvgPrcCptn': '1510',
#       'wtAvgPrcDisc': '1535.21',
#       'trqu': '3174559',
#       'trPrc': '4837814795'},
#      {'basDt': '20230405',
#       'oilCtg': '경유',
#       'wtAvgPrcCptn': '1370.18',
#       'wtAvgPrcDisc': '1391.01',
#       'trqu': '9130400',
#       'trPrc': '12665466320'}]}}}}
