# %%
import pandas as pd
from datetime import datetime, timedelta
import requests
import time 
import re
from google.cloud import bigquery
from bs4 import BeautifulSoup

# %%
url = 'https://www.data.go.kr/tcs/dss/selectDataSetList.do?dType=API&keyword=&detailKeyword=&publicDataPk=&recmSe=&detailText=&relatedKeyword=&commaNotInData=&commaAndData=&commaOrData=&must_not=&tabId=&dataSetCoreTf=&coreDataNm=&sort=reqCo&relRadio=&orgFullName=&orgFilter=&org=&orgSearch=&currentPage=9&perPage=40&brm=%EC%8B%9D%ED%92%88%EA%B1%B4%EA%B0%95&instt=%EA%B3%B5%EA%B3%B5%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EA%B5%AD%EA%B0%80%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EC%9C%84%EC%9B%90%ED%9A%8C%2C%EC%9E%85%EB%B2%95%EA%B8%B0%EA%B4%80%2C%ED%97%8C%EB%B2%95%EA%B8%B0%EA%B4%80&svcType=&kwrdArray=&extsn=&coreDataNmArray=&pblonsipScopeCode='

# %%
urls = [
    'https://www.data.go.kr/tcs/dss/selectDataSetList.do?dType=API&keyword=&detailKeyword=&publicDataPk=&recmSe=&detailText=&relatedKeyword=&commaNotInData=&commaAndData=&commaOrData=&must_not=&tabId=&dataSetCoreTf=&coreDataNm=&sort=reqCo&relRadio=&orgFullName=&orgFilter=&org=&orgSearch=&currentPage=1&perPage=40&brm=%EC%8B%9D%ED%92%88%EA%B1%B4%EA%B0%95&instt=%EA%B3%B5%EA%B3%B5%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EA%B5%AD%EA%B0%80%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EC%9C%84%EC%9B%90%ED%9A%8C%2C%EC%9E%85%EB%B2%95%EA%B8%B0%EA%B4%80%2C%ED%97%8C%EB%B2%95%EA%B8%B0%EA%B4%80&svcType=&kwrdArray=&extsn=&coreDataNmArray=&pblonsipScopeCode=',
    'https://www.data.go.kr/tcs/dss/selectDataSetList.do?dType=API&keyword=&detailKeyword=&publicDataPk=&recmSe=&detailText=&relatedKeyword=&commaNotInData=&commaAndData=&commaOrData=&must_not=&tabId=&dataSetCoreTf=&coreDataNm=&sort=reqCo&relRadio=&orgFullName=&orgFilter=&org=&orgSearch=&currentPage=2&perPage=40&brm=%EC%8B%9D%ED%92%88%EA%B1%B4%EA%B0%95&instt=%EA%B3%B5%EA%B3%B5%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EA%B5%AD%EA%B0%80%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EC%9C%84%EC%9B%90%ED%9A%8C%2C%EC%9E%85%EB%B2%95%EA%B8%B0%EA%B4%80%2C%ED%97%8C%EB%B2%95%EA%B8%B0%EA%B4%80&svcType=&kwrdArray=&extsn=&coreDataNmArray=&pblonsipScopeCode=',
    'https://www.data.go.kr/tcs/dss/selectDataSetList.do?dType=API&keyword=&detailKeyword=&publicDataPk=&recmSe=&detailText=&relatedKeyword=&commaNotInData=&commaAndData=&commaOrData=&must_not=&tabId=&dataSetCoreTf=&coreDataNm=&sort=reqCo&relRadio=&orgFullName=&orgFilter=&org=&orgSearch=&currentPage=3&perPage=40&brm=%EC%8B%9D%ED%92%88%EA%B1%B4%EA%B0%95&instt=%EA%B3%B5%EA%B3%B5%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EA%B5%AD%EA%B0%80%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EC%9C%84%EC%9B%90%ED%9A%8C%2C%EC%9E%85%EB%B2%95%EA%B8%B0%EA%B4%80%2C%ED%97%8C%EB%B2%95%EA%B8%B0%EA%B4%80&svcType=&kwrdArray=&extsn=&coreDataNmArray=&pblonsipScopeCode=',
    'https://www.data.go.kr/tcs/dss/selectDataSetList.do?dType=API&keyword=&detailKeyword=&publicDataPk=&recmSe=&detailText=&relatedKeyword=&commaNotInData=&commaAndData=&commaOrData=&must_not=&tabId=&dataSetCoreTf=&coreDataNm=&sort=reqCo&relRadio=&orgFullName=&orgFilter=&org=&orgSearch=&currentPage=4&perPage=40&brm=%EC%8B%9D%ED%92%88%EA%B1%B4%EA%B0%95&instt=%EA%B3%B5%EA%B3%B5%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EA%B5%AD%EA%B0%80%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EC%9C%84%EC%9B%90%ED%9A%8C%2C%EC%9E%85%EB%B2%95%EA%B8%B0%EA%B4%80%2C%ED%97%8C%EB%B2%95%EA%B8%B0%EA%B4%80&svcType=&kwrdArray=&extsn=&coreDataNmArray=&pblonsipScopeCode=',
    'https://www.data.go.kr/tcs/dss/selectDataSetList.do?dType=API&keyword=&detailKeyword=&publicDataPk=&recmSe=&detailText=&relatedKeyword=&commaNotInData=&commaAndData=&commaOrData=&must_not=&tabId=&dataSetCoreTf=&coreDataNm=&sort=reqCo&relRadio=&orgFullName=&orgFilter=&org=&orgSearch=&currentPage=5&perPage=40&brm=%EC%8B%9D%ED%92%88%EA%B1%B4%EA%B0%95&instt=%EA%B3%B5%EA%B3%B5%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EA%B5%AD%EA%B0%80%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EC%9C%84%EC%9B%90%ED%9A%8C%2C%EC%9E%85%EB%B2%95%EA%B8%B0%EA%B4%80%2C%ED%97%8C%EB%B2%95%EA%B8%B0%EA%B4%80&svcType=&kwrdArray=&extsn=&coreDataNmArray=&pblonsipScopeCode=',
    'https://www.data.go.kr/tcs/dss/selectDataSetList.do?dType=API&keyword=&detailKeyword=&publicDataPk=&recmSe=&detailText=&relatedKeyword=&commaNotInData=&commaAndData=&commaOrData=&must_not=&tabId=&dataSetCoreTf=&coreDataNm=&sort=reqCo&relRadio=&orgFullName=&orgFilter=&org=&orgSearch=&currentPage=6&perPage=40&brm=%EC%8B%9D%ED%92%88%EA%B1%B4%EA%B0%95&instt=%EA%B3%B5%EA%B3%B5%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EA%B5%AD%EA%B0%80%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EC%9C%84%EC%9B%90%ED%9A%8C%2C%EC%9E%85%EB%B2%95%EA%B8%B0%EA%B4%80%2C%ED%97%8C%EB%B2%95%EA%B8%B0%EA%B4%80&svcType=&kwrdArray=&extsn=&coreDataNmArray=&pblonsipScopeCode=',
    'https://www.data.go.kr/tcs/dss/selectDataSetList.do?dType=API&keyword=&detailKeyword=&publicDataPk=&recmSe=&detailText=&relatedKeyword=&commaNotInData=&commaAndData=&commaOrData=&must_not=&tabId=&dataSetCoreTf=&coreDataNm=&sort=reqCo&relRadio=&orgFullName=&orgFilter=&org=&orgSearch=&currentPage=7&perPage=40&brm=%EC%8B%9D%ED%92%88%EA%B1%B4%EA%B0%95&instt=%EA%B3%B5%EA%B3%B5%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EA%B5%AD%EA%B0%80%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EC%9C%84%EC%9B%90%ED%9A%8C%2C%EC%9E%85%EB%B2%95%EA%B8%B0%EA%B4%80%2C%ED%97%8C%EB%B2%95%EA%B8%B0%EA%B4%80&svcType=&kwrdArray=&extsn=&coreDataNmArray=&pblonsipScopeCode=',
    'https://www.data.go.kr/tcs/dss/selectDataSetList.do?dType=API&keyword=&detailKeyword=&publicDataPk=&recmSe=&detailText=&relatedKeyword=&commaNotInData=&commaAndData=&commaOrData=&must_not=&tabId=&dataSetCoreTf=&coreDataNm=&sort=reqCo&relRadio=&orgFullName=&orgFilter=&org=&orgSearch=&currentPage=8&perPage=40&brm=%EC%8B%9D%ED%92%88%EA%B1%B4%EA%B0%95&instt=%EA%B3%B5%EA%B3%B5%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EA%B5%AD%EA%B0%80%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EC%9C%84%EC%9B%90%ED%9A%8C%2C%EC%9E%85%EB%B2%95%EA%B8%B0%EA%B4%80%2C%ED%97%8C%EB%B2%95%EA%B8%B0%EA%B4%80&svcType=&kwrdArray=&extsn=&coreDataNmArray=&pblonsipScopeCode=',
    'https://www.data.go.kr/tcs/dss/selectDataSetList.do?dType=API&keyword=&detailKeyword=&publicDataPk=&recmSe=&detailText=&relatedKeyword=&commaNotInData=&commaAndData=&commaOrData=&must_not=&tabId=&dataSetCoreTf=&coreDataNm=&sort=reqCo&relRadio=&orgFullName=&orgFilter=&org=&orgSearch=&currentPage=9&perPage=40&brm=%EC%8B%9D%ED%92%88%EA%B1%B4%EA%B0%95&instt=%EA%B3%B5%EA%B3%B5%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EA%B5%AD%EA%B0%80%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EC%9C%84%EC%9B%90%ED%9A%8C%2C%EC%9E%85%EB%B2%95%EA%B8%B0%EA%B4%80%2C%ED%97%8C%EB%B2%95%EA%B8%B0%EA%B4%80&svcType=&kwrdArray=&extsn=&coreDataNmArray=&pblonsipScopeCode=',
    'https://www.data.go.kr/tcs/dss/selectDataSetList.do?dType=API&keyword=&detailKeyword=&publicDataPk=&recmSe=&detailText=&relatedKeyword=&commaNotInData=&commaAndData=&commaOrData=&must_not=&tabId=&dataSetCoreTf=&coreDataNm=&sort=reqCo&relRadio=&orgFullName=&orgFilter=&org=&orgSearch=&currentPage=10&perPage=40&brm=%EC%8B%9D%ED%92%88%EA%B1%B4%EA%B0%95&instt=%EA%B3%B5%EA%B3%B5%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EA%B5%AD%EA%B0%80%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EC%9C%84%EC%9B%90%ED%9A%8C%2C%EC%9E%85%EB%B2%95%EA%B8%B0%EA%B4%80%2C%ED%97%8C%EB%B2%95%EA%B8%B0%EA%B4%80&svcType=&kwrdArray=&extsn=&coreDataNmArray=&pblonsipScopeCode='
    ]


title    = []
info     = []
format1  = []
format2  = []
text     = []
url_in   = []
data_type= []

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.141 Safari/537.36'}


for url in urls:
    CPG = requests.get(url, headers=headers).text
    bsObj = BeautifulSoup(CPG, 'html.parser')
    print(url)
    for i in range(len(bsObj('span', {'class' :"title"}))):
        title_ = bsObj('span', {'class' :"title"})[i].text.replace('\t', '').replace('\n', '').replace('\r', '')
        info_ = bsObj('div', {'class' :"info-data"})[i]('span', {'class' :"data"})[0].text.replace('\t', '').replace('\n', '').replace('\r', '')
        try:
            format1_ = bsObj('dl')[i]('span', {'class' : 'tagset xml'})[0].text.replace('\t', '').replace('\n', '').replace('\r', '')
        except:
            format1_ = ''
        try:
            format2_ = bsObj('dl')[i]('span', {'class' : 'tagset json'})[0].text.replace('\t', '').replace('\n', '').replace('\r', '')
        except:
            format2_ = ''
        text_ = bsObj('dd', {'class' :'ellipsis publicDataDesc'})[i].text.strip()

        url_   = 'https://www.data.go.kr' + bsObj('dl')[i]('a')[0]['href']
        temp_page  = requests.get(url_, headers=headers).text
        temp_page2 = BeautifulSoup(temp_page, 'html.parser')
        type_      = temp_page2('td', {'class' : 'td custom-cell-border-bottom'})[4].text
        
        title.append(title_)
        info.append(info_)
        format1.append(format1_)
        format2.append(format2_)
        text.append(text_)
        data_type.append(type_)
        url_in.append(url_)
# Out:
# https://www.data.go.kr/tcs/dss/selectDataSetList.do?dType=API&keyword=&detailKeyword=&publicDataPk=&recmSe=&detailText=&relatedKeyword=&commaNotInData=&commaAndData=&commaOrData=&must_not=&tabId=&dataSetCoreTf=&coreDataNm=&sort=reqCo&relRadio=&orgFullName=&orgFilter=&org=&orgSearch=&currentPage=1&perPage=40&brm=%EC%8B%9D%ED%92%88%EA%B1%B4%EA%B0%95&instt=%EA%B3%B5%EA%B3%B5%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%EA%B8%B0%EA%B4%80%2C%EA%B5%90%EC%9C%A1%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EA%B5%AD%EA%B0%80%ED%96%89%EC%A0%95%EA%B8%B0%EA%B4%80%2C%EC%9C%84%EC%9B%90%ED%9A%8C%2C%EC%9E%85%EB%B2%95%EA%B8%B0%EA%B4%80%2C%ED%97%8C%EB%B2%95%EA%B8%B0%EA%B4%80&svcType=&kwrdArray=&extsn=&coreDataNmArray=&pblonsipScopeCode=
# ...

# %%
df = pd.DataFrame()
df['제공기관'] = title
df['제목'] = info
df['API 유형'] = data_type
df['데이터포맷1'] = format1
df['데이터포맷2'] = format2
df['내용'] = text
df['LINK'] = url_in

# %%
df
# Out:
#                                      제공기관             제목 API 유형 데이터포맷1 데이터포맷2  \
# 0                  농림수산식품교육문화정보원_레시피 재료정보  농림수산식품교육문화정보원   LINK    XML   JSON
# 1                  농림수산식품교육문화정보원_레시피 기본정보  농림수산식품교육문화정보원   LINK    XML   JSON
# 2                   식품의약품안전처_조리식품의 레시피 DB       식품의약품안전처   LINK    XML   JSON
# 3                      식품의약품안전처_바코드연계제품정보       식품의약품안전처   LINK    XML   JSON
# 4             식품의약품안전처_건강기능식품 기능성 원료인정 현황       식품의약품안전처   LINK    XML   JSON
# ..                                    ...            ...    ...    ...    ...
# 357  식품의약품안전처_코로나 관련 의약품 임상시험 계획 시험책임자 정보       식품의약품안전처   REST    XML   JSON
# 358         한국식품안전관리인증원_HACCP 심사수수료정보 서비스    한국식품안전관리인증원   REST    XML   JSON
# 359     한국식품안전관리인증원_축산물운반업 HACCP업체 정보 서비스    한국식품안전관리인증원   REST    XML   JSON
# 360          식품의약품안전처_의약품 임상시험 계획 선정기준 정보       식품의약품안전처   REST    XML   JSON
# 361     한국식품안전관리인증원_HACCP 업무관리시스템코드정보 서비스    한국식품안전관리인증원   REST    XML   JSON
#
# ...

# %%
excel_name = './211019_API_rawdata_v2.xlsx'
df.to_excel(excel_name, sheet_name= 'Sheet1' )
