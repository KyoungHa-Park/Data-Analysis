# %%
# !pip install PyMySQL
# !pip install Jinja2
# !pip install scikit-image
# !pip install email-to

# %%
###############
# 1. import
#####
import pandas as pd
from datetime import datetime, timedelta
import re
import time 
from bs4 import BeautifulSoup

# local only
import os
import pymysql
import pandas as pd
import matplotlib.pyplot as plt
from skimage import io

import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

path = 'C:/windows/Fonts/malgun.ttf'                           # 폰트:맑은고딕
font_name = fm.FontProperties(fname=path, size=24).get_name()  
plt.rc('font', family=font_name)

# 크롤링 
import re
from bs4 import BeautifulSoup
from selenium import webdriver

# 한글정제 KoNLPy
from ckonlpy.tag import Twitter
twitter = Twitter()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
import chromedriver_autoinstaller
path = chromedriver_autoinstaller.install() 
driver = webdriver.Chrome(path)

# %%
# driver = webdriver.Chrome(f'C:/Users/MAEIL/Downloads/{chrome_ver}/chromedriver.exe')
# try:
#     driver = webdriver.Chrome(f'C:/Users/MAEIL/Downloads/{chrome_ver}/chromedriver.exe')
# except:
#     chromedriver_autoinstaller.install(True)
#     driver = webdriver.Chrome(f'C:/Users/MAEIL/Downloads/{chrome_ver}/chromedriver.exe')
#     driver = webdriver.Chrome(f'C:/Users/MAEIL/Downloads/chromedriver/chromedriver.exe')   

driver.implicitly_wait(3)
driver.maximize_window()

# %%
##########
# Web 드라이버 실행/page접속 
#####

url = 'https://sell.smartstore.naver.com/'

driver.get(url)
driver.implicitly_wait(5)

# 화면이동
driver.find_elements_by_xpath('/html/body/ui-view[1]/div[2]/div[2]/div/div[1]/div[2]/a[2]')[0].click() 
driver.implicitly_wait(5)

# 로그인조건 이동
driver.find_elements_by_xpath('/html/body/ui-view[1]/div[3]/div/div/div/form/div[1]/ul/li[2]/a')[0].click() 
driver.implicitly_wait(5)

# ID/PW 넣기
driver.find_element_by_name('id').send_keys('xyzmagic')  #사용자 ID
driver.find_element_by_name('pw').send_keys('Pkhunm4y6!!') #사용자 PASSWORD

# 로그인 진행
driver.find_elements_by_xpath('//*[@id="log.login"]')[0].click() 
driver.implicitly_wait(10)

# %%
try:
    driver.find_elements_by_xpath('/html/body/div[1]/div/div/div[3]/div[1]/button')[0].click()
    driver.find_elements_by_xpath('/html/body/div[2]/div/div/div[3]/div/button[2]')[0].click()
except:
    pass

# %%
##########
# 1.Web 드라이버 실행/page접속 
#####

url = 'https://sell.smartstore.naver.com/'

driver.get(url)
driver.implicitly_wait(5)

# 화면이동
driver.find_elements_by_xpath('/html/body/ui-view[1]/div[2]/div[2]/div/div[1]/div[2]/a[2]')[0].click() 
driver.implicitly_wait(5)

# 로그인조건 이동
driver.find_elements_by_xpath('/html/body/ui-view[1]/div[3]/div/div/div/form/div[1]/ul/li[2]/a')[0].click() 
driver.implicitly_wait(5)

# ID/PW 넣기
driver.find_element_by_name('id').send_keys('xyzmagic')  #사용자 ID
driver.find_element_by_name('pw').send_keys('Pkhunm4y6!!') #사용자 PASSWORD

# 로그인 진행
driver.find_elements_by_xpath('//*[@id="log.login"]')[0].click() 
driver.implicitly_wait(10)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-f22d1f2dede8> in <module>
#       9
#      10 # 화면이동
# ---> 11 driver.find_elements_by_xpath('/html/body/ui-view[1]/div[2]/div[2]/div/div[1]/div[2]/a[2]')[0].click()
#      12 driver.implicitly_wait(5)
#      13
#
# IndexError: list index out of range

# %%
# 이상한 광고창 제거
try:
    driver.find_elements_by_xpath('/html/body/div[1]/div/div/div[3]/div[1]/button')[0].click()
    driver.implicitly_wait(10)
    time.sleep(1)
    driver.find_elements_by_xpath('/html/body/div[2]/div/div/div[3]/div/button[2]')[0].click()
    driver.implicitly_wait(5)
except:
    pass

# %%
# 리뷰관리 페이지 이동
driver.find_elements_by_xpath('//*[@id="seller-lnb"]/div/div[1]/ul/li[5]/a')[0].click()
time.sleep(1)
driver.find_elements_by_xpath('//*[@id="seller-lnb"]/div/div[1]/ul/li[5]/ul/li[3]/a')[0].click()
time.sleep(1)

# %%
# 리뷰조건 : 전체 제외
driver.find_elements_by_xpath('//*[@id="seller-content"]/div/div[1]/form/div/div[1]/div/ul/li[6]/div/div[1]/div[1]/div[2]/div/label[1]/span')[0].click()

# 리뷰조건 : 평점 3,4,5, 제외
driver.find_elements_by_xpath('//*[@id="seller-content"]/div/div[1]/form/div/div[1]/div/ul/li[6]/div/div[1]/div[1]/div[2]/div/label[4]/span')[0].click()
driver.find_elements_by_xpath('//*[@id="seller-content"]/div/div[1]/form/div/div[1]/div/ul/li[6]/div/div[1]/div[1]/div[2]/div/label[5]/span')[0].click()
driver.find_elements_by_xpath('//*[@id="seller-content"]/div/div[1]/form/div/div[1]/div/ul/li[6]/div/div[1]/div[1]/div[2]/div/label[6]/span')[0].click()

# 리뷰조건 : 블라인드 제외
driver.find_elements_by_xpath('//*[@id="seller-content"]/div/div[1]/form/div/div[1]/div/ul/li[6]/div/div[3]/div/div[2]/div/label[1]/span')[0].click()
time.sleep(1)
driver.find_elements_by_xpath('//*[@id="seller-content"]/div/div[1]/form/div/div[1]/div/ul/li[6]/div/div[3]/div/div[2]/div/label[3]/span')[0].click()

# 답글여부 : 미답변
driver.find_elements_by_xpath('//*[@id="seller-content"]/div/div[1]/form/div/div[1]/div/ul/li[6]/div/div[1]/div[2]/div[2]/div')[0].click()
driver.find_elements_by_xpath('//*[@id="seller-content"]/div/div[1]/form/div/div[1]/div/ul/li[6]/div/div[1]/div[2]/div[2]/div/div[2]/div/div[3]')[0].click()
driver.implicitly_wait(5)
time.sleep(2)

# 검색버튼 클릭
driver.find_elements_by_xpath('//*[@id="seller-content"]/div/div[1]/form/div/div[2]/div/button[1]')[0].click()
driver.implicitly_wait(5)
driver.find_elements_by_xpath('//*[@id="seller-content"]/div/div[1]/form/div/div[2]/div/button[1]')[0].click()
time.sleep(2)

# %%
# Excel 다운로드 클릭
driver.find_elements_by_xpath('//*[@id="seller-content"]/div/div[2]/div/div[1]/div[2]/div/div/button')[0].click()
driver.implicitly_wait(5)
time.sleep(5)

# %%
driver.close()

# %%
from os import listdir
# 경로 설정
directory_name = r'C:/Users/MAEIL/Downloads/'

# 파일명 가져오기
file_names = listdir(directory_name)

for i in range(0, len( file_names)):
    text = re.findall(r'review_(.*?).xlsx',file_names[i])
    if len(text) == 1:
        file_name = 'review_' + str(text[0]) + '.xlsx'
        break

df1 = pd.read_excel(directory_name + file_name , 0, header = 0)

df1 = df1[['상품번호', '상품명', '구매자평점', '리뷰상세내용', '등록자', '리뷰등록일']]
df1['수집체널'] = '네이버'

naver_count = len(df1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:214: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df1 = pd.read_excel('./review_20220304_092207.xlsx' , 0, header = 0)

df1 = df1[['상품번호', '상품명', '구매자평점', '리뷰상세내용', '등록자', '리뷰등록일']]
df1['수집체널'] = '네이버'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:214: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
###############
# 2.자료 추출
#####

# DB연결
conn = pymysql.connect(host = '10.223.7.4', user ='MAEIL_CS', password = "Maeil01!@", database='MAEIL_CS')

# cursor 설정
cursor = conn.cursor(pymysql.cursors.DictCursor)


#자료 불러오기 : 전날 부정리뷰 겟수
sql= '''select DATE_FORMAT (CURDATE(), '%a') as week'''
cursor.execute(sql)
gubun = cursor.fetchall()
gubun = pd.DataFrame(gubun)
gubun = gubun['week'][0]

if gubun =='Mon':
    sql_cnt= '''select count(distinct CONTENTS) as CNT
            FROM MAEIL_REVIEW A
            where GRADE in (1,2)
            and WRITE_DT between DATE_SUB(CURDATE(), INTERVAL 3 DAY) and (CURDATE())
            '''
    sql= '''select PRODUCT_NO as "상품번호"
        , GROUP_CONCAT( distinct (SELECT concat(  '(', code, ') ' , code_nm) FROM JT_CODE B WHERE A.PRODUCT_CODE = B.CODE AND B.CODE_GRP_ID = 'PRODUCT') SEPARATOR ', ') as "상품명"
        , A.GRADE as "구매자평점" 
        , A.CONTENTS as 리뷰내용상세
        , A.WRITER as "등록자" 
        , A.WRITE_DT as 리뷰등록일 
        , (SELECT CODE_NM FROM JT_CODE B WHERE A.COMPANY_CODE = B.CODE AND B.CODE_GRP_ID = 'DEALER_ID') as 수집체널 
        FROM MAEIL_REVIEW A
        where GRADE in (1,2)
        and A.COMPANY_CODE in (13261)
        and WRITE_DT between DATE_SUB(CURDATE(), INTERVAL 3 DAY) and (CURDATE())
        and PRODUCT_CODE not like 'G_%'
        group by A.COMPANY_CODE, A.WRITER, A.CONTENTS, A.WRITE_DT, A.GRADE, A.PRODUCT_NO
        order by A.COMPANY_CODE, A.GRADE desc
        '''
else:
    sql_cnt= '''select count(distinct CONTENTS) as CNT
            FROM MAEIL_REVIEW A
            where GRADE in (1,2)
            and WRITE_DT between DATE_SUB(CURDATE(), INTERVAL 1 DAY) and (CURDATE())
            '''
    sql= '''select PRODUCT_NO as "상품번호"
        , GROUP_CONCAT( distinct (SELECT concat(  '(', code, ') ' , code_nm) FROM JT_CODE B WHERE A.PRODUCT_CODE = B.CODE AND B.CODE_GRP_ID = 'PRODUCT') SEPARATOR ', ') as "상품명"
        , A.GRADE as "구매자평점" 
        , A.CONTENTS as 리뷰상세내용
        , A.WRITER as "등록자" 
        , A.WRITE_DT as 리뷰등록일 
        , (SELECT CODE_NM FROM JT_CODE B WHERE A.COMPANY_CODE = B.CODE AND B.CODE_GRP_ID = 'DEALER_ID') as 수집체널 
        FROM MAEIL_REVIEW A
        where GRADE in (1,2)
        and A.COMPANY_CODE in (13261)
        and WRITE_DT between DATE_SUB(CURDATE(), INTERVAL 1 DAY) and (CURDATE())
        and PRODUCT_CODE not like 'G_%'
        group by A.COMPANY_CODE, A.WRITER, A.CONTENTS, A.WRITE_DT, A.GRADE, A.PRODUCT_NO
        order by A.COMPANY_CODE, A.GRADE desc
        '''
        
cursor.execute(sql_cnt)
result0 = cursor.fetchall()
result0 = pd.DataFrame(result0)
result0 = len(result0)

cursor.execute(sql)
result5 = cursor.fetchall()
# result = cursor.fetchmany(3)
result5 = pd.DataFrame(result5)

# %%
kakao_count = len(result5)

# %%
result = pd.concat([df1, result5], sort=False)
if len(result) == 0:
    result = df = pd.DataFrame({ '수집체널': ['(해당사항 없음)'], '내용': ['(해당사항 없음)'] })

# %%
kakao_count = len(result5)

# %%
# kakao_count, naver_count
# result

# %%
###############
# Text 정제
#####

# 사전에 고유 명사 추가
twitter.add_dictionary('콜드브루', 'Noun')
twitter.add_dictionary('무설탕', 'Noun')
twitter.add_dictionary('오트밀크', 'Noun')
twitter.add_dictionary('종이빨대', 'Noun')
twitter.add_dictionary('프로틴', 'Noun')
twitter.add_dictionary('보냉백', 'Noun')
twitter.add_dictionary('라방', 'Noun')
twitter.add_dictionary('재구매', 'Noun')
twitter.add_dictionary('유통기한', 'Noun')
twitter.add_dictionary('서울우유', 'Noun')
twitter.add_dictionary('매일두유', 'Noun')
twitter.add_dictionary('사은품', 'Noun')
twitter.add_dictionary('어메이징 오트', 'Noun')
twitter.add_dictionary('언스위트', 'Noun')
twitter.add_dictionary('아몬드브리즈', 'Noun')
twitter.add_dictionary('아몬드 브리즈', 'Noun')
twitter.add_dictionary('오리지널', 'Noun')
twitter.add_dictionary('오리지날', 'Noun')
twitter.add_dictionary('언스윗트', 'Noun')
twitter.add_dictionary('의향', 'Noun')



def tokenize(doc):
    result = ['/'.join(t) for t in twitter.pos(doc, norm=True, stem=True)] # ex '더빙/Norm', '나다/Verb'
    return result 

def listToString(s):  
    str1 = ""  
    for ele in s:  
        str1 += " " + ele.strip()  
    return str1

#토큰화 : 전체리뷰자료
df_temp1 = result['리뷰상세내용'].replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# regex to konlpy
token_all = [list(dict.fromkeys(tokenize(row))) for row in df_temp1]

data_trim2 = []
for i in range(len(df_temp1)):
    t = ' '.join(token_all[i])
    data_trim2.append(t.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]",""))
    
df_temp1 = pd.DataFrame(data_trim2)
df_temp1 = df_temp1[0].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")

result['token'] = df_temp1
result['token_attribution'] = token_all
result['lenght'] = result['token_attribution'].str.len()
result['token_attribution2'] = data_trim2

result = result.sort_values(by ='lenght', axis=0, ascending=False, ignore_index = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:50: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
###############
# 필터링 후 키워드 입력, "중요도 역순"으로 진행
#####

# 미분류값 fill
result['유형'] = '(미분류)'

def get_keyword(keyword, gubun):
    result.loc[(result['token'].str.contains(str(keyword))), '관련내용'] = keyword
    result.loc[(result['관련내용'] ==keyword), '유형'] = gubun

# 제품 키워드
keyword2 = ['맛', '밍밍', '고소', '비리다', '냄새', '맛없다', '비싸다', '효과', '녹다', '뭉치다', '달다', '유산균', '단백',
            '서울우유','귀리', '귀리우유','오트밀크','오트','오틀리','베지밀','아몬드','두유','텁텁','오리지날', '언스위트',
            '빨대', '환경','패키지', '식이섬유', '아침', '달달', '담백', '당' ]

for word in keyword2:
    get_keyword(word, '제품')


# 배송 키워드
keyword1 = ['빠르다', '배송', '포장', '택배', '상자', '배송', '반품', '환불',
            '파업', '터지다', '늦다', '취소', '유통기한', '임박', '깨다', 
           ] 

for word in keyword1:
    get_keyword(word, '배송')

# %%
# result = result[['유형', '관련내용', '리뷰상세내용','구매자평점', '상품명', '상품번호', '등록자', '리뷰등록일', ]]
result = result.sort_values(by ='유형', ascending= False).reset_index(drop=True)

# %%
pd.pivot_table(result, values='구매자평점', index=['관련내용'],columns=['유형'],  aggfunc='count').fillna('-')
# Out:
# 유형     배송   제품
# 관련내용
# 깨다    1.0    -
# 늦다    2.0    -
# 당       -  1.0
# 맛없다     -  1.0
# 배송    4.0    -
# 유통기한  1.0    -
# 임박    1.0    -
# 취소    3.0    -
# 택배    2.0    -
# 터지다   2.0    -
# 파업    2.0    -

# %%
result
# Out:
#        유형  관련내용                                             리뷰상세내용  구매자평점  \
# 0      제품   맛없다                                         양도 적고 맛없어요      2
# 1      제품     당                                  당이 너무 높아요..아기껀데..      1
# 2      배송    택배         택배는 엄청 느렸고 고객센터 연락안됨\n제품은 만족하지만 다시는 구매안할래요      1
# 3      배송    취소  배송 완전 느려요ㅡㅡ\n아기 먹일건데 너무 느려서 취소하려다 참았네요\n이럴거면 쿠...      2
# 4      배송    늦다  이제품은아니구요 액상분유를반품한지가 언제인데 아직도환불이 왜 어째서 무엇때문에 않되...      1
# 5      배송   터지다  양송이크림스프 한 개가 박스 속에서 터져서 엉망진창이었어요 나머지 것들도 다 닦아야...      1
# 6      배송    배송  2월 10일 전에 2개 9900원이었는데 품절처리 후 가격 올렸더라고요 그래도 제가...      1
# 7      배송  유통기한  구매 후 배송중에 2천원이나 할인하여 판매하네요. \n유통기한도 동일하구요. \n전...      2
# 8      배송    배송  상황 설명없이 분리 배송하고....\n이미 다 처리 된 후에 답변 하시고....\n...      2
# 9      배송    파업  배송은  최악 입니다  택배 파업은 이해 합니다  그렇다고  소비자보고  계속 기다...      1
# 10     배송    배송  정기배송 2주에 한 번 선택했는데 3주가 다돼서 오네요. 이렇게 맘대로 보낼거면 정...      1
# 11     배송    파업  일전에 택배파업핑계로 1달동안 배송안하던 메일유업 대리점이있어서 거기피힌다고 시킨건...      1
# 12     배송    깨다         여러개가 깨져서 내용물 흘러나와서 난감했는데 어쨋든 해결해주셔서 고맙습니다.      2
# 13     배송    택배       택배기사가 얼마나 상품을 던졌으면 박스가 찢어져서 오나요! 너무 기분 나쁘네요!      1
# 14     배송    취소          단계를 잘못 시켜서 배송 취소했는데... 무시하고도착해버렸네요.......      2
# 15     배송    배송                      배송이 느렸습니다. \n구매시 사전 고지가 없었구요.      1
# 16     배송    취소                            너무늦게왔고\n 취소요청했는데도 안되고ㅜㅜ      2
# 17     배송    임박                               유통기한이 임박한 상품이라 실망입니다      2
# 18     배송    늦다                                 배송이너무늦음  상품배송이너무느림      1
# 19     배송   터지다  주방에서 너무 이상한 냄새가 나서 원인을 찾다가 발견한 박스 바닥&hellip; 이...      1
# 20  (미분류)   NaN                                      늘 이용하고 있어요 ㅎㅎ      1
#
#                                                   상품명        상품번호  \
# 0                        썬업 과일야채 샐러드 ABC 주스 125ml 24팩  6013070219
# 1                           요미요미 튼튼주스 배&도라지 125ml 24팩  6035283048
# 2                         [매일유업] 아몬드브리즈 프로틴 190ml 48팩  4733807521
# 3           [매일유업] 소화가 잘되는 우유(락토프리) 오리지널 멸균 190ml 24팩  5341766839
# 4   [리뷰5,000포인트][매일유업] 리뉴얼 앱솔루트 명작 2FL 분유 2단계, 800...  5947218439
# 5                 [5+5][매일유업] 상하키친 클램차우더스프 150g 5입+5입  6273785817
# 6         [1+1][페레로] 그랜드 로쉐 초콜릿 125g 밀크 1개+다크 1개(총2개)  4697488041
# 7           [쿠폰적용가14900원] 상하목장 무항생제인증 멸균 우유 125ml 24팩  6117029699
# 8   [슈퍼위크] [팩홀더증정] 요미요미 유기농주스 과일믹스 125ml 24팩+요미요미 ...  5242079745
# 9                        [매일유업] 아몬드브리즈 오리지널 190ml 24팩  2540929238
# 10          ★[정기구독] 소화가 잘되는 우유(락토프리) 저지방 멸균 190ml 24팩  4936458013
# 11              ★[정기구독] 소화가 잘되는 우유(락토프리) 멸균 190ml 24팩  4936460564
# 12  [쿠폰적용가 9,900원] 데르뜨 젤리 혼합 세트130g (오렌지 3입+백도 6입)_냉장  6083327410
# 13                        상하목장 유기농 멸균 우유 딸기 125ml 24팩  2547654233
# 14  [리뷰1,800포인트][매일유업] 리뉴얼 앱솔루트 명작 2FL 분유 2단계, 800...  5947231076
# 15           [페레로] [리뷰1,000포인트]로쉐 T5 5개입 12개 (총 60개입)  4697491470
# 16        [1+1][페레로] 그랜드 로쉐 초콜릿 125g 밀크 1개+다크 1개(총2개)  4697488041
# 17              ★[정기구독] 소화가 잘되는 우유(락토프리) 멸균 190ml 24팩  4936460564
# 18      [매일유업] 리뉴얼 앱솔루트 명작 2FL 분유 1단계, 800g 3개, 0~6개월  5946817178
# 19          [매일유업] 셀렉스 마시는 단백질 오리지널 파우치 125ml 14입 2박스  3648535811
# 20     [최대11%적립이벤트][오늘출발] 상하목장 유기농 멸균 우유 백색 200ml 24팩  4568404023
#
#              등록자                 리뷰등록일
# 0     gmld******  2022.03.03. 21:23:32
# 1     2006******  2022.03.03. 23:33:01
# 2       daan****  2022.02.27. 19:11:37
# 3    rmat*******  2022.03.03. 02:21:53
# 4        boos***  2022.03.03. 22:38:31
# 5      newe*****  2022.02.26. 17:52:48
# 6   visu********  2022.02.28. 08:15:20
# 7         fa****  2022.03.03. 21:24:04
# 8      shin*****  2022.02.28. 19:05:12
# 9      sins*****  2022.02.27. 23:07:50
# 10       8806***  2022.02.26. 00:16:23
# 11       jjy8***  2022.02.27. 14:22:51
# 12      lake****  2022.03.02. 13:29:44
# 13        ka****  2022.02.26. 12:30:48
# 14    expe******  2022.03.03. 19:25:35
# 15      boss****  2022.02.26. 08:30:42
# 16       woom***  2022.03.01. 12:46:43
# 17        pr****  2022.03.03. 22:27:52
# 18        dh****  2022.02.28. 07:43:01
# 19      vict****  2022.03.02. 00:35:01
# 20   movi*******  2022.03.01. 13:58:42

# %%
import send_email_v2 as se
from jinja2 import Template

###############
# 3.이메일 발송
#####

# 이메일 양식(내용) frame 구성하기
message_tmpl="""
<html>
    <!DOCTYPE html>
    <html>
    <head lang ="ko">
      <meta charset ="UTF-8">
      <title>{{title1}}</title>
    </head>
    <BODY style="FONT-SIZE: 10pt; font-family: 맑은고딕, Malgun Gothic, dotum, gulim, sans-serif">
    안녕하세요,<br>
    <br>
    {{send_date}}시 기준, 직영채널의 부정리뷰 현황 내용 공유드립니다.<br>
    <br>
    <b>1. 전체 직영 채널 부정 리뷰 : {{count1}} 개</b><br>
    <br>
    <b>2. 관리 가능 채널 부정 리뷰 : {{count2}} 개</b><br>
    &nbsp;&nbsp;- 네이버  : {{ count3 }} 개<br>
    &nbsp;&nbsp;- 카카오 톡스토어  : {{ count4 }} 개<br>
    <br>
    <b>3. 부정리뷰 List</b><br>
    {{ df_html }}<br>
    <br>
    <SPAN style="COLOR: #808080">{{add_text1}}</SPAN><br>
    <SPAN style="COLOR: #808080">{{add_text2}}</SPAN><br>
    <br>
    감사합니다.<br>
    <br>
    </BODY>
</html>"""

# 이메일 양식(내용) 변동 내용 정의
render_data = {
    'send_date' : (datetime.today()).strftime('%Y-%m-%d, %H'),
    'df_html' : result.to_html(),
    'count1' : int(result0) + int(naver_count) ,
    'count2' : int(naver_count) + int(kakao_count),
    'count3' : naver_count,
    'count4' : kakao_count,
    'add_text1' : "*  본 메일은 발신전용입니다.",
    'add_text2' : "** (내용/기술문의 : 고객정보전략담당, 박경하 )"
}


t= Template(message_tmpl)
html_report = t.render(render_data)

# %%
# 발송 변수 설정

# 받는사람 : test 발송
# to_users = ['khpark@maeil.com']

# 받는사람 : mulit 발송
to_users = ['khpark@maeil.com', 'cappygirl@maeil.com', 'intosky82@maeil.com', 'jinto170@maeil.com', 'k8802@maeil.com', 'billy@maeil.com', 'pigangel@maeil.com', 's.t.jeong@maeil.com', 'gmlrud852@maeil.com']


# 메일제목
now = datetime.today()    # 현재
date = now.strftime('%Y%m%d')

subject = "[자동발송] 네이버 고객 부정리뷰 관리 List(TEST_v5)"

# 본문
html = html_report

# 첨부파일 추가
try:
    attach = directory_name + file_name
except:
    attach = None
graph=None

#메일 발송
se.send_email(to_users, subject, html, graph, attach)

# os.remove(attach)

# exit()
